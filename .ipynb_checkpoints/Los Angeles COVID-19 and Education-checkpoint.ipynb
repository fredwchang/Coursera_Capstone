# %%
##Import
import pandas as pd
import numpy as pd
import json
import pip
# !pip install lxml html5lib beautifulsoup4
# !pip install geopy
from geopy.geocoders import Nominatim 
# !pip install opencage
from opencage.geocoder import OpenCageGeocode
from pprint import pprint
import matplotlib.cm as cm
import matplotlib.colors as colors
# !conda install -c conda-forge folium=0.5.0
from pandas.io.json import json_normalize
import folium
import requests
import urllib.request
import csv
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt  
# %matplotlib inline 
print('Libraries imported.')
# Out:
# Requirement already satisfied: lxml in c:\users\fred\anaconda3\lib\site-packages (4.6.1)
# Requirement already satisfied: html5lib in c:\users\fred\anaconda3\lib\site-packages (1.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\fred\anaconda3\lib\site-packages (4.9.3)
# Requirement already satisfied: webencodings in c:\users\fred\anaconda3\lib\site-packages (from html5lib) (0.5.1)
# Requirement already satisfied: six>=1.9 in c:\users\fred\anaconda3\lib\site-packages (from html5lib) (1.15.0)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\fred\anaconda3\lib\site-packages (from beautifulsoup4) (2.0.1)
# Requirement already satisfied: geopy in c:\users\fred\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: geographiclib<2,>=1.49 in c:\users\fred\anaconda3\lib\site-packages (from geopy) (1.50)
# Collecting opencage
#   Downloading opencage-1.2.2-py3-none-any.whl (6.1 kB)
# Requirement already satisfied: six>=1.4.0 in c:\users\fred\anaconda3\lib\site-packages (from opencage) (1.15.0)
# Requirement already satisfied: Requests>=2.2.0 in c:\users\fred\anaconda3\lib\site-packages (from opencage) (2.24.0)
# Collecting backoff>=1.10.0
#   Downloading backoff-1.10.0-py2.py3-none-any.whl (31 kB)
# Requirement already satisfied: pyopenssl>=0.15.1 in c:\users\fred\anaconda3\lib\site-packages (from opencage) (19.1.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\fred\anaconda3\lib\site-packages (from Requests>=2.2.0->opencage) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\fred\anaconda3\lib\site-packages (from Requests>=2.2.0->opencage) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fred\anaconda3\lib\site-packages (from Requests>=2.2.0->opencage) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\fred\anaconda3\lib\site-packages (from Requests>=2.2.0->opencage) (1.25.11)
# Requirement already satisfied: cryptography>=2.8 in c:\users\fred\anaconda3\lib\site-packages (from pyopenssl>=0.15.1->opencage) (3.1.1)
# Requirement already satisfied: cffi!=1.11.3,>=1.8 in c:\users\fred\anaconda3\lib\site-packages (from cryptography>=2.8->pyopenssl>=0.15.1->opencage) (1.14.3)
# Requirement already satisfied: pycparser in c:\users\fred\anaconda3\lib\site-packages (from cffi!=1.11.3,>=1.8->cryptography>=2.8->pyopenssl>=0.15.1->opencage) (2.20)
# Installing collected packages: backoff, opencage
# Successfully installed backoff-1.10.0 opencage-1.2.2
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... doneLibraries imported.
#
#
# # All requested packages already installed.

# %% [markdown]
# <h2> Data Acquistion </h2>

# %% [markdown]
# <h3> Data Uploading </h3>

# %% [markdown]
# Cases per City in LA County

# %%
url = 'http://publichealth.lacounty.gov/media/coronavirus/locations.htm#top-25'
response = requests.get(url)
print(response.status_code)
soup = BeautifulSoup(response.text,"html.parser")
##Input the table you want to scrape
table = soup.findAll('table',{"class":"overflow-y"})[0]
values =[]
# CHOOSE HOW MANY
tr = table.findAll(['tr'])[1:225]
csvFile = open("cases.csv",'wt',newline='',encoding='utf-8')
writer = csv.writer(csvFile)  
try:   
        for cell in tr:
            th = cell.find_all('th')
            th_data = [col.text.strip('\n') for col in th]
            td = cell.find_all('td')
            row = [i.text.replace('\n','') for i in td]
            writer.writerow(th_data+row)      
        
finally:   
    csvFile.close()
# Out:
# 200

# %%
from IPython.display import HTML
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
Click here to <a href="javascript:code_toggle()">Hide</a> the input coding.''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# Click here to <a href="javascript:code_toggle()">Hide</a> the input coding.

# %% [markdown]
# Reload into Pandas and Clean Up Dataset

# %%
import pandas as pd
df.cases= pd.read_csv("cases.csv", header=None)
##Rename Columns
df.cases.columns = ['Name', 'Cases', 'Case Rate', 'Death', 'Death Rate']
## Strip City of, Strip Los Angeles - 
df.cases['Name'] = df.cases['Name'].str.replace(r'City of', '')
df.cases['Name'] = df.cases['Name'].str.replace(r'Los Angeles -', '')
df.cases['Name'] = df.cases['Name'].str.replace(r'*', '')
df.cases['Name'] = df.cases['Name'].str.replace(r'/Cove', '')
df.cases['Name'] = df.cases['Name'].str.replace(r'/Cochran', '')
df.cases.head(50)
# Out:
#                      Name  Cases  Case Rate  Death  Death Rate
# 0            Agoura Hills    797       3817     11          53
# 1                Alhambra   5722       6598    108         125
# 2                 Arcadia   2199       3808     75         130
# 3                 Artesia   1683      10021     35         208
# 4                  Avalon      9        233      0           0
# 5                   Azusa   5349      10689     73         146
# 6            Baldwin Park  11372      14813    186         242
# 7                    Bell   5723      15752     77         212
# 8            Bell Gardens   7158      16619     61         142
# 9              Bellflower   9083      11685    110         142
# 10          Beverly Hills   2094       6066     20          58
# 11               Bradbury     32       2993      0           0
# 12                Burbank   6989       6521    160         149
# 13              Calabasas    931       3828     15          62
# 14                 Carson   7555       8050    122         130
# 15               Cerritos   2434       4861     26          52
# 16              Claremont   1874       5136     36          99
# 17               Commerce   2148      16436     28         214
# 18                Compton  14313      14327    145         145
# 19                 Covina   5461      11138     98         200
# 20                 Cudahy   4105      16860     34         140
# 21            Culver City   1769       4437     61         153
# 22            Diamond Bar   2622       4559     30          52
# 23                 Downey  15104      13219    165         144
# 24                 Duarte   1933       8780     57         259
# 25               El Monte  14760      12586    277         236
# 26             El Segundo    535       3187      4          24
# 27                Gardena   5142       8387    114         186
# 28               Glendale  15363       7440    380         184
# 29               Glendora   3974       7532    114         216
# 30       Hawaiian Gardens   1917      13062      4          27
# 31              Hawthorne   8418       9481    116         131
# 32          Hermosa Beach    769       3910      7          36
# 33           Hidden Hills     65       3439      0           0
# 34        Huntington Park   9836      16536    106         178
# 35               Industry    127      29062      3         686
# 36              Inglewood  11168       9833    200         176
# 37              Irwindale    217      14873      3         206
# 38   La Canada Flintridge    624       3016     12          58
# 39       La Habra Heights     91       1668      1          18
# 40              La Mirada   3526       7109     65         131
# 41              La Puente   5771      14180     61         150
# 42               La Verne   2337       7022     33          99
# 43               Lakewood   5933       7383     37          46
# 44              Lancaster  17921      11092    162         100
# 45               Lawndale   2840       8449     29          86
# 46                 Lomita   1087       5244     11          53
# 47                Lynwood  11443      15883    167         232
# 48                 Malibu    288       2222      6          46
# 49        Manhattan Beach   1017       2825      9          25

# %%
df.cases.shape
# Out:
# (224, 5)

# %% [markdown]
# <h2> Describe Data Set of Cases and Deaths in Los Angeles</h2>

# %%
##Drop the Rates and Describe cases
drop_these = ['Case Rate', 'Death Rate']
cases_final = df.cases.drop(columns=drop_these)
cases_final.describe()
# Out:
#                Cases        Death
# count     224.000000   224.000000
# mean     5643.504464    80.700893
# std     28147.882940   399.210268
# min         5.000000     0.000000
# 25%       761.000000     8.000000
# 50%      2164.500000    35.000000
# 75%      5523.500000    75.000000
# max    420111.000000  5960.000000

# %%
cases_final.shape
# Out:
# (224, 3)

# %%
cases_final.boxplot(column=['Cases'], showfliers=False)
plt.title('COVID-19 Cases in LA County')
plt.show()

# %%
cases_final.boxplot(column=['Death'], showfliers=False)
plt.title('COVID-19 Deaths in LA County')
plt.show()

# %% [markdown]
# <h2> Long/Lat Acquisition </h2>

# %%
## Add CA to the Location to help with specificity of Geo Search
z = cases_final[['Name','Cases','Death']].copy()
z['Name'] = z['Name'].str.strip()
z['Name'] = z['Name'].astype(str) +', CA' 
z.tail(75)
# Out:
#                        Name  Cases  Death
# 149   Little Bangladesh, CA   2260     16
# 150        Little Tokyo, CA    341      7
# 151            Longwood, CA    493      5
# 152           Los Feliz, CA    856     13
# 153   Manchester Square, CA    769      7
# ..                      ...    ...    ...
# 219            Westwood, CA   2019     18
# 220  Wholesale District, CA   5512     71
# 221          Wilmington, CA   6838     49
# 222     Wilshire Center, CA   4454     68
# 223            Winnetka, CA   5624     49
#
# [75 rows x 3 columns]

# %%
## Drop locations that Geocoder can't fetch correctly
z = z.drop(index=[98,99,102,104,108,110,111,112,121,123,127,129,137,149,151,156,159,160,161,162,167,176,179,183,185,186,195,196,197,209,210,212,216,222])
z.tail(50)
# Out:
#                        Name  Cases  Death
# 155           Mar Vista, CA   1602     21
# 157             Melrose, CA   6680    147
# 158            Mid-city, CA    979     28
# 163     North Hollywood, CA  17091    198
# 164          Northridge, CA   6105     96
# 165   Pacific Palisades, CA    605     12
# 166             Pacoima, CA  14695    141
# 168               Palms, CA   2106     39
# 169       Panorama City, CA  11397    173
# 170        Park La Brea, CA    472      1
# 171          Pico-Union, CA   6122    142
# 172       Playa Del Rey, CA     83      0
# 173         Playa Vista, CA    475      3
# 174        Porter Ranch, CA   2004     21
# 175         Rancho Park, CA    280      1
# 177              Reseda, CA   9678    201
# 178        Reseda Ranch, CA    543      1
# 180           San Pedro, CA   5731     74
# 181        Shadow Hills, CA    304      2
# 182        Sherman Oaks, CA   4622     60
# 184       South Carthay, CA    582      5
# 187         Studio City, CA   1057     32
# 188          Sun Valley, CA   7877     87
# 189             Sunland, CA   1846     40
# 190     Sycamore Square, CA     25      2
# 191              Sylmar, CA  13566    164
# 192             Tarzana, CA   2711     56
# 193      Temple-Beaudry, CA   4303     72
# 194           Thai Town, CA    711      9
# 198             Tujunga, CA   2243     38
# 199    University Hills, CA    232      1
# 200     University Park, CA   2783     36
# 201         Valley Glen, CA   3134     41
# 202      Valley Village, CA   1652     46
# 203            Van Nuys, CA  12303    205
# 204              Venice, CA   1257     12
# 205      Vermont Knolls, CA   2453     34
# 206      Vermont Square, CA   1264     10
# 207       Vermont Vista, CA   6446     57
# 208      Vernon Central, CA   9745    101
# 211               Watts, CA   6444     65
# 213          West Adams, CA   3381    100
# 214          West Hills, CA   2410     71
# 215    West Los Angeles, CA   1889     28
# 217         Westchester, CA   1853     31
# 218            Westlake, CA   6624    199
# 219            Westwood, CA   2019     18
# 220  Wholesale District, CA   5512     71
# 221          Wilmington, CA   6838     49
# 223            Winnetka, CA   5624     49

# %%
z.shape
# Out:
# (190, 3)

# %%
##Check if Nominatim works or not
address='Hawaiian Gardens, CA'
geolocator = Nominatim(user_agent="Your_Name")
location = geolocator.geocode(address)
print(location.address)
print((location.latitude, location.longitude))
# Out:
# Hawaiian Gardens, Los Angeles County, California, United States
# (33.8284787, -118.0743137)

# %%
## Code Long/Lat and Add to Table
geolocator = Nominatim(user_agent="Fw")
z['Long'] = z['Name'].apply(geolocator.geocode).apply(lambda x: x.longitude)
z['Lat'] = z['Name'].apply(geolocator.geocode).apply(lambda x: x.latitude)
z
# Out:
#                        Name  Cases  Death        Long        Lat
# 0          Agoura Hills, CA    797     11 -118.765704  34.147910
# 1              Alhambra, CA   5722    108 -118.127060  34.093042
# 2               Arcadia, CA   2199     75 -118.040150  34.136207
# 3               Artesia, CA   1683     35 -118.079620  33.869020
# 4                Avalon, CA      9      0 -118.327261  33.342210
# ..                      ...    ...    ...         ...        ...
# 218            Westlake, CA   6624    199 -118.272820  34.062923
# 219            Westwood, CA   2019     18 -118.430635  34.056121
# 220  Wholesale District, CA   5512     71 -118.235434  34.036575
# 221          Wilmington, CA   6838     49 -118.262509  33.780016
# 223            Winnetka, CA   5624     49 -118.571006  34.197449
#
# [190 rows x 5 columns]

# %%
##Create Marker Size to help with Death Markers
locsize = z[['Name','Cases','Death','Lat','Long']].copy()
locsize['size']=locsize['Death'].apply(lambda count:12 if count>=200 else
                                         8 if count>=150 and count<200 else
                                         4 if count>=75 and count<150 else
                                         1 if count>=25 and count<75 else
                                         0.1)
locsize
# Out:
#                        Name  Cases  Death        Lat        Long  size
# 0          Agoura Hills, CA    797     11  34.147910 -118.765704   0.1
# 1              Alhambra, CA   5722    108  34.093042 -118.127060   4.0
# 2               Arcadia, CA   2199     75  34.136207 -118.040150   4.0
# 3               Artesia, CA   1683     35  33.869020 -118.079620   1.0
# 4                Avalon, CA      9      0  33.342210 -118.327261   0.1
# ..                      ...    ...    ...        ...         ...   ...
# 218            Westlake, CA   6624    199  34.062923 -118.272820   8.0
# 219            Westwood, CA   2019     18  34.056121 -118.430635   0.1
# 220  Wholesale District, CA   5512     71  34.036575 -118.235434   1.0
# 221          Wilmington, CA   6838     49  33.780016 -118.262509   1.0
# 223            Winnetka, CA   5624     49  34.197449 -118.571006   1.0
#
# [190 rows x 6 columns]

# %%
## Create Map/HeatMap
from folium.plugins import HeatMap
LaCovid = folium.Map(location=[34, -118], zoom_start=9.6)
HeatMap(data=locsize[['Lat', 'Long', 'Cases']].groupby(['Lat', 'Long']).sum().reset_index().values.tolist(), radius=20, blur=10, max_val=45).add_to(LaCovid)
##Create Markers
z_d = folium.map.FeatureGroup()
for Lat, Long, Size in zip(locsize['Lat'],locsize['Long'], locsize['size']):
    ## locsize.Lat, locsize.Long, locsize.size
    z_d.add_child(
        folium.features.CircleMarker(
            [Lat, Long],
            name='Deaths',
            radius=Size, # define how big you want the circle markers to be
            color='black',
            fill=True,
            fill_color='black',
            fill_opacity=0.3
        )
    )

# %%
##TIMESTAMP

url_timestamp = 'http://publichealth.lacounty.gov/media/coronavirus/locations.htm#top-25'
tsresponse = requests.get(url_timestamp)
tssoup = BeautifulSoup(tsresponse.text,"html.parser")
timestamp = tssoup.find('div', attrs={"class":"container-xl pb-4"})
timestamp2=tssoup.find('small', class_= "text-muted")
timestampstring=timestamp2.text[5:23]
print(timestampstring)
# Out:
#  6:00pm 01/19/2021

# %% [markdown]
# <h2>"COVID-19 Cases Heat Map in Los Angeles County"</h2>

# %%
LaCovid
LaCovid.add_child(z_d)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawgit.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%20%23map_cf44a1ab59bc4345a482473a7870020f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%20%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%20%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//leaflet.github.io/Leaflet.heat/dist/leaflet-heat.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_cf44a1ab59bc4345a482473a7870020f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20var%20bounds%20%3D%20null%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%0A%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_cf44a1ab59bc4345a482473a7870020f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%27map_cf44a1ab59bc4345a482473a7870020f%27%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7Bcenter%3A%20%5B34%2C-118%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20zoom%3A%209.6%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%2 ...

# %%
print("According to LA County, last updated:")
print(timestampstring)
# Out:
# According to LA County, last updated:
#  6:00pm 01/19/2021

# %% [markdown]
# Based on the mapping, we can see a heatmap of Los Angeles County in regards to cases. The more red an area is noted, the more cases we have noted in that area. We also see black circles that represent deaths in Los Angeles County. Again, the larger the circles, the more deaths are noted in that geography. Please keep in mind, the data is shown of <i><b>Los Angeles County</b></i> and therefore there was limited data from Long Beach, Orange County, Inland Empire, etc, when interpreting this data.
#
# We can see that there is significant amount of cases in South Los Angeles, Inglewood, Pomona,and San Fernando Valley. We can also see that there are more deaths in these areas as well, which makes sense following high case rates. We will now conduct further correlation studies to see if education status plays a role in COVID.

# %% [markdown]
# <h3> Append with other data </h3>

# %%
##Start Append System
cases_final.head()
df.cases.append = cases_final[['Name','Cases','Death']].copy()

# %%
##Import Income from LA County

import requests
incomeurl = "http://publichealth.lacounty.gov/ohae/docs/cchp/xlsx/2018/MedianIncome.xlsx"
resp = requests.get(incomeurl)

output = open('income.csv', 'wb')
output.write(resp.content)
output.close()
import pandas as pd
df.income= pd.read_excel("income.csv", header=None)
df.income.head(20)
# Out:
#      0               1         2                                      3  \
# 0  NaN             NaN       NaN                                    NaN
# 1  NaN             NaN       NaN                                    NaN
# 2  NaN             NaN       NaN                                    NaN
# 3  NaN             NaN       NaN                                    NaN
# 4  NaN  City/Community  Estimate  95% Confidence Interval2: Lower Limit
# 5  NaN        Alhambra     53582                                50105.4
# 6  NaN        Altadena     86050                                81905.3
# 7  NaN         Arcadia     79934                                74551.2
# 8  NaN           Azusa     53135                                  49472
# 9  NaN    Baldwin Park     51742                                49903.9
# 10 NaN            Bell     37269                                34785.5
# 11 NaN    Bell Gardens     37882                                35347.1
# 12 NaN      Bellflower     48823                                46840.3
# 13 NaN   Beverly Hills     97327                                84154.4
# 14 NaN         Burbank     66076                                63266.3
# 15 NaN       Calabasas    106050                                97423.6
# 16 NaN          Carson     72421                                69098.6
# 17 NaN        Cerritos     90321                                84977.6
# 18 NaN       Claremont     88523                                81133.6
# 19 NaN         Compton     43507                                41065.4
#
#                                        4
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4   95% Confidence Interval: Upper Limit
# 5                                57058.6
# 6                                90194.7
# 7                                85316.8
# 8                                  56798
# 9                                53580.1
# 10                               39752.5
# 11                               40416.9
# 12                               50805.7
# 13                                110500
# 14                               68885.7
# 15                                114676
# 16                               75743.4
# 17                               95664.4
# 18                               95912.4
# 19                               45948.6

# %%
##Cleanse Income Data
df.income.columns = ['Drop', 'Name','Income', 'CI1', 'CI2']
df.income_a = df.income.drop(['Drop','CI1','CI2'], axis=1)

df.income_a = df.income_a.dropna()
df.income_b = df.income_a.reset_index(drop=True)
df.income_c = df.income_b.iloc[1:]
df.income_c.head(90)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-390-b239279f2a45> in <module>
#       1 ##Cleanse Income Data
# ----> 2 df.income.columns = ['Drop', 'Name','Income', 'CI1', 'CI2']
#       3 df.income_a = df.income.drop(['Drop','CI1','CI2'], axis=1)
#       4
#       5 df.income_a = df.income_a.dropna()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    5150         try:
#    5151             object.__getattribute__(self, name)
# -> 5152             return object.__setattr__(self, name, value)
#    5153         except AttributeError:
#    5154             pass
#
# pandas\_libs\properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     562     def _set_axis(self, axis: int, labels: Index) -> None:
#     563         labels = ensure_index(labels)
# --> 564         self._mgr.set_axis(axis, labels)
#     565         self._clear_item_cache()
#     566
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in set_axis(self, axis, new_labels)
#     224
#     225         if new_len != old_len:
# --> 226             raise ValueError(
#     227                 f"Length mismatch: Expected axis has {old_len} elements, new "
#     228                 f"values have {new_len} elements"
#
# ValueError: Length mismatch: Expected axis has 2 elements, new values have 5 elements

# %%
df.cases_append['Name'] = df.cases_append['Name'].str.strip()
df.income_c['Name'] = df.income_c['Name'].str.strip()
c = pd.merge(df.cases_append, df.income_c, how='inner',left_on='Name', right_on = 'Name', sort=False)
c['Name'] =  c['Name'].astype(str) +', CA' 
c.head(10)
# Out:
# <ipython-input-523-a9a62f18f2dd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.income_c['Name'] = df.income_c['Name'].str.strip()
#                 Name  Cases  Death  Income
# 0       Alhambra, CA   5722    108   53582
# 1        Arcadia, CA   2199     75   79934
# 2          Azusa, CA   5349     73   53135
# 3   Baldwin Park, CA  11372    186   51742
# 4           Bell, CA   5723     77   37269
# 5   Bell Gardens, CA   7158     61   37882
# 6     Bellflower, CA   9083    110   48823
# 7  Beverly Hills, CA   2094     20   97327
# 8        Burbank, CA   6989    160   66076
# 9      Calabasas, CA    931     15  106050

# %%
##Import Education from LA County
import pandas as pd
df.edu= pd.read_excel("Education Index.xlsx", header=None)
df.edu.columns = ['Name', 'Edu Index']
df.edu['Name'] =  df.edu['Name'].astype(str) +', CA' 
df.edu.shape
# Out:
# (88, 2)

# %%
df.final = pd.merge(c, df.edu, how='inner',left_on='Name', right_on = 'Name', sort=False)
df.final
# Out:
#                        Name  Cases  Death  Income Edu Index
# 0              Alhambra, CA   5722    108   53582     0.804
# 1               Arcadia, CA   2199     75   79934       0.9
# 2                 Azusa, CA   5349     73   53135     0.789
# 3          Baldwin Park, CA  11372    186   51742     0.627
# 4                  Bell, CA   5723     77   37269     0.483
# 5          Bell Gardens, CA   7158     61   37882     0.429
# 6            Bellflower, CA   9083    110   48823     0.798
# 7         Beverly Hills, CA   2094     20   97327     0.918
# 8               Burbank, CA   6989    160   66076     0.888
# 9             Calabasas, CA    931     15  106050     0.936
# 10               Carson, CA   7555    122   72421      0.81
# 11             Cerritos, CA   2434     26   90321     0.915
# 12            Claremont, CA   1874     36   88523     0.915
# 13              Compton, CA  14313    145   43507     0.621
# 14               Covina, CA   5461     98   64813     0.885
# 15               Cudahy, CA   4105     34   36429     0.435
# 16          Culver City, CA   1769     61   81189       0.9
# 17          Diamond Bar, CA   2622     30   89221     0.909
# 18               Downey, CA  15104    165   62897     0.774
# 19             El Monte, CA  14760    277   38085     0.579
# 20              Gardena, CA   5142    114   47674     0.834
# 21             Glendale, CA  15363    380   52574     0.837
# 22             Glendora, CA   3974    114   75148     0.927
# 23            Hawthorne, CA   8418    116   44504     0.756
# 24      Huntington Park, CA   9836    106   34887     0.417
# 25            Inglewood, CA  11168    200   42044     0.759
# 26            La Mirada, CA   3526     65   79330     0.909
# 27            La Puente, CA   5771     61   56512     0.615
# 28             La Verne, CA   2337     33   74631     0.942
# 29             Lakewood, CA   5933     37   79193     0.915
# 30            Lancaster, CA  17921    162   47225      0.84
# 31             Lawndale, CA   2840     29   47540     0.729
# 32              Lynwood, CA  11443    167   43109     0.528
# 33      Manhattan Beach, CA   1017      9  143527     0.936
# 34              Maywood, CA   4497     56   35582     0.423
# 35             Monrovia, CA   2651     50   70358     0.909
# 36           Montebello, CA   8788    102   45875      0.72
# 37        Monterey Park, CA   3986    117   54097     0.774
# 38              Norwalk, CA  13643    186   59756      0.75
# 39             Palmdale, CA  20415    159   52392     0.765
# 40            Paramount, CA   8571     83   45792     0.594
# 41          Pico Rivera, CA   9588    147   55752     0.693
# 42               Pomona, CA  21206    277   49186     0.687
# 43  Rancho Palos Verdes, CA   1028     35  118780     0.951
# 44        Redondo Beach, CA   2129     19  105145     0.948
# 45             Rosemead, CA   3988     77   44906      0.66
# 46            San Dimas, CA   2584     50   78034     0.939
# 47         San Fernando, CA   4378     41   55170     0.582
# 48          San Gabriel, CA   2648    148   51579     0.768
# 49        Santa Clarita, CA  16096    136   83554     0.921
# 50         Santa Monica, CA   3641     97   76580     0.918
# 51           South Gate, CA  16085    135   43552     0.537
# 52       South Pasadena, CA   1096     33   78957      0.93
# 53          Temple City, CA   1958     77   64372     0.858
# 54             Torrance, CA   5558    121   79549     0.927
# 55               Walnut, CA   1439     23  100184     0.909
# 56          West Covina, CA  10854    124   69189     0.852
# 57       West Hollywood, CA   1782     21   56317     0.936
# 58             Whittier, CA   9417    158   66457     0.852

# %%
df.final['Income']=df.final['Income'].astype('float64')
df.final['Edu Index']=df.final['Edu Index'].astype('float64')
df.final
# Out:
#                        Name  Cases  Death    Income  Edu Index
# 0              Alhambra, CA   5722    108   53582.0      0.804
# 1               Arcadia, CA   2199     75   79934.0      0.900
# 2                 Azusa, CA   5349     73   53135.0      0.789
# 3          Baldwin Park, CA  11372    186   51742.0      0.627
# 4                  Bell, CA   5723     77   37269.0      0.483
# 5          Bell Gardens, CA   7158     61   37882.0      0.429
# 6            Bellflower, CA   9083    110   48823.0      0.798
# 7         Beverly Hills, CA   2094     20   97327.0      0.918
# 8               Burbank, CA   6989    160   66076.0      0.888
# 9             Calabasas, CA    931     15  106050.0      0.936
# 10               Carson, CA   7555    122   72421.0      0.810
# 11             Cerritos, CA   2434     26   90321.0      0.915
# 12            Claremont, CA   1874     36   88523.0      0.915
# 13              Compton, CA  14313    145   43507.0      0.621
# 14               Covina, CA   5461     98   64813.0      0.885
# 15               Cudahy, CA   4105     34   36429.0      0.435
# 16          Culver City, CA   1769     61   81189.0      0.900
# 17          Diamond Bar, CA   2622     30   89221.0      0.909
# 18               Downey, CA  15104    165   62897.0      0.774
# 19             El Monte, CA  14760    277   38085.0      0.579
# 20              Gardena, CA   5142    114   47674.0      0.834
# 21             Glendale, CA  15363    380   52574.0      0.837
# 22             Glendora, CA   3974    114   75148.0      0.927
# 23            Hawthorne, CA   8418    116   44504.0      0.756
# 24      Huntington Park, CA   9836    106   34887.0      0.417
# 25            Inglewood, CA  11168    200   42044.0      0.759
# 26            La Mirada, CA   3526     65   79330.0      0.909
# 27            La Puente, CA   5771     61   56512.0      0.615
# 28             La Verne, CA   2337     33   74631.0      0.942
# 29             Lakewood, CA   5933     37   79193.0      0.915
# 30            Lancaster, CA  17921    162   47225.0      0.840
# 31             Lawndale, CA   2840     29   47540.0      0.729
# 32              Lynwood, CA  11443    167   43109.0      0.528
# 33      Manhattan Beach, CA   1017      9  143527.0      0.936
# 34              Maywood, CA   4497     56   35582.0      0.423
# 35             Monrovia, CA   2651     50   70358.0      0.909
# 36           Montebello, CA   8788    102   45875.0      0.720
# 37        Monterey Park, CA   3986    117   54097.0      0.774
# 38              Norwalk, CA  13643    186   59756.0      0.750
# 39             Palmdale, CA  20415    159   52392.0      0.765
# 40            Paramount, CA   8571     83   45792.0      0.594
# 41          Pico Rivera, CA   9588    147   55752.0      0.693
# 42               Pomona, CA  21206    277   49186.0      0.687
# 43  Rancho Palos Verdes, CA   1028     35  118780.0      0.951
# 44        Redondo Beach, CA   2129     19  105145.0      0.948
# 45             Rosemead, CA   3988     77   44906.0      0.660
# 46            San Dimas, CA   2584     50   78034.0      0.939
# 47         San Fernando, CA   4378     41   55170.0      0.582
# 48          San Gabriel, CA   2648    148   51579.0      0.768
# 49        Santa Clarita, CA  16096    136   83554.0      0.921
# 50         Santa Monica, CA   3641     97   76580.0      0.918
# 51           South Gate, CA  16085    135   43552.0      0.537
# 52       South Pasadena, CA   1096     33   78957.0      0.930
# 53          Temple City, CA   1958     77   64372.0      0.858
# 54             Torrance, CA   5558    121   79549.0      0.927
# 55               Walnut, CA   1439     23  100184.0      0.909
# 56          West Covina, CA  10854    124   69189.0      0.852
# 57       West Hollywood, CA   1782     21   56317.0      0.936
# 58             Whittier, CA   9417    158   66457.0      0.852

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 
df.final.corr()
# Out:
#               Cases     Death    Income  Edu Index
# Cases      1.000000  0.794521 -0.499149  -0.371105
# Death      0.794521  1.000000 -0.471435  -0.230363
# Income    -0.499149 -0.471435  1.000000   0.755002
# Edu Index -0.371105 -0.230363  0.755002   1.000000

# %%
sns.regplot(x="Cases", y="Death", data=df.final)
plt.ylim(0,)
# Out:
# (0.0, 398.55)

# %%
sns.regplot(x="Income", y="Cases", data=df.final)
plt.ylim(0,)
# Out:
# (0.0, 22570.4185755774)

# %%
sns.regplot(x="Income", y="Death", data=df.final)
plt.ylim(0,)
# Out:
# (0.0, 402.0647809629684)

# %%
sns.regplot(x="Edu Index", y="Cases", data=df.final)
plt.ylim(0,)
# Out:
# (0.0, 22219.75)

# %%
sns.regplot(x="Edu Index", y="Death", data=df.final)
plt.ylim(0,)
# Out:
# (0.0, 398.55)

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(df.final['Death'], df.final['Cases'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.7945209080966835  with a P-value of P = 5.877617806942353e-14

# %%
pearson_coef, p_value = stats.pearsonr(df.final['Edu Index'], df.final['Cases'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.3711051301253169  with a P-value of P = 0.0038081997012900035

# %%
pearson_coef, p_value = stats.pearsonr(df.final['Edu Index'], df.final['Death'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.2303631565604891  with a P-value of P = 0.07921047297729891

# %%
pearson_coef, p_value = stats.pearsonr(df.final['Income'], df.final['Cases'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.49914879561675085  with a P-value of P = 5.717325513385932e-05

# %%
pearson_coef, p_value = stats.pearsonr(df.final['Income'], df.final['Death'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is -0.4714354718298873  with a P-value of P = 0.00016397170721499846
